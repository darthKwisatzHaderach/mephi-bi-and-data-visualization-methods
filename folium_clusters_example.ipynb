# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы.
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

df = pd.read_csv('/datasets/moscow_malls_info.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef888b99afc87e78c51aada3c2eababd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef888b99afc87e78c51aada3c2eababd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef888b99afc87e78c51aada3c2eababd = L.map(
#                 &quot;map_ef888b99afc87e78c51aada3c2eababd&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c75b753432a9c14c1f68a875a46cc307 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef888b99afc87e78c51aada3c2eababd);
#
#
#             var marker_83f78025943298e660350a3c76c90278 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_ef888b99afc87e78c51aada3c2eababd);
#
#
#         var popup_a682ef42a299f050c5efa9001e1c1558 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f86c251ce7ac6204832c70988d5b5471 = $(`&lt;div id=&quot;html_f86c251ce7ac6204832c70988d5b5471&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_a682ef42a299f050c5efa9001e1c1558.setContent(html_f86c251ce7ac6204832c70988d5b5471);
#
#
#
#         marker_83f78025943298e660350a3c76c90278.bindPopup(popup_a682ef42a299f050c5efa9001e1c1558)
#         ;
#
#
#
#
#             var marker_0271f93cd98d0c1d3a7d47717a31f210 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_ef888b99afc87e78c51aada3c2eababd);
#
#
#         var popup_5c8c6b4542a1cdf248213602a5f361a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36e609e96e6bf4eebdf3de3d015a24e8 = $(`&lt;div id=&quot;html_36e609e96e6bf4eebdf3de3d015a24e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_5c8c6b4542a1cdf248213602a5f361a8.setContent(html_36e609e96e6bf4eebdf3de3d015a24e8);
#
#
#
#         marker_0271f93cd98d0c1d3a7d47717a31f210.bindPopup(popup_5c8c6b4542a1cdf248213602a5f361a8)
#         ;
#
#
#
#
#             var marker_bc7933cc1bdff89a8e06160d6a9b9140 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_ef888b99afc87e78c51aada3c2eababd);
#
#
#         var popup_57176873c0311fbd4b5c21b07cb6c976 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bfff93164edd4f93871cc1da9fb95c77 = $(`&lt;div id=&quot;html_bfff93164edd4f93871cc1da9fb95c77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_57176873c0311fbd4b5c21b07cb6c976.setContent(html_bfff93164edd4f93871cc1da9fb95c77);
#
#
#
#         marker_bc7933cc1bdff89a8e06160d6a9b9140.bindPopup(popup_57176873c0311fbd4b5c21b07cb6c976)
#         ;
#
#
#
#
#             var marker_1e2c297a9b3a303d971f0b5f1f72989a = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_ef888b99afc87e78c51aada3c2eababd);
#
#
#         var popup_1a24bdf96493cebf4028f983857ea52e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93a8a6fcd1d9402530eefbb9e0ed608f = $(`&lt;div id=&quot;html_93a8a6fcd1d9402530eefbb9e0ed608f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_1a24bdf96493cebf4028f983857ea52e.setContent(html_93a8a6fcd1d9402530eefbb9e0ed608f);
#
#
#
#         marker_1e2c297a9b3a303d971f0b5f1f72989a.bindPopup(popup_1a24bdf96493cebf4028f983857ea52e)
#         ;
#
#
#
#
#             var marker_447b17fc25c115e07a9de9b5db046f47 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_ef888b99afc87e78c51aada3c2eababd);
#
#
#         var popup_3aecca3806fb58825ec701443e0415ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b83eecfae6a6e63dd7ef240394150cc1 = $(`&lt;div id=&quot;html_b83eecfae6a6e63dd7ef240394150cc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_3aecca3806fb58825ec701443e0415ff.setContent(html_b83eecfae6a6e63dd7ef240394150cc1);
#
#
#
#         marker_447b17fc25c115e07a9de9b5db046f47.bindPopup(popup_3aecca3806fb58825ec701443

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46871798a7584233a2af7b8d7eb949e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46871798a7584233a2af7b8d7eb949e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46871798a7584233a2af7b8d7eb949e0 = L.map(
#                 &quot;map_46871798a7584233a2af7b8d7eb949e0&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b7c6912fac45dd34e41c951c135ee0f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46871798a7584233a2af7b8d7eb949e0);
#
#
#             var marker_0e298ef4cd15cfed8ac012658b748c69 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_46871798a7584233a2af7b8d7eb949e0);
#
#
#         var popup_e922dff82a37dff3a9fa9aa787a0a342 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29e8f6ac1d2966d124ac841c0b6a0986 = $(`&lt;div id=&quot;html_29e8f6ac1d2966d124ac841c0b6a0986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_e922dff82a37dff3a9fa9aa787a0a342.setContent(html_29e8f6ac1d2966d124ac841c0b6a0986);
#
#
#
#         marker_0e298ef4cd15cfed8ac012658b748c69.bindPopup(popup_e922dff82a37dff3a9fa9aa787a0a342)
#         ;
#
#
#
#
#             var marker_f0d6d54f2e20dd18749c89d44a8055b0 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_46871798a7584233a2af7b8d7eb949e0);
#
#
#         var popup_37b5ed1aad5d1d5dbd61727916f12413 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa60acba7ae8cc4a9d1c92e6142818db = $(`&lt;div id=&quot;html_aa60acba7ae8cc4a9d1c92e6142818db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_37b5ed1aad5d1d5dbd61727916f12413.setContent(html_aa60acba7ae8cc4a9d1c92e6142818db);
#
#
#
#         marker_f0d6d54f2e20dd18749c89d44a8055b0.bindPopup(popup_37b5ed1aad5d1d5dbd61727916f12413)
#         ;
#
#
#
#
#             var marker_7675df93a1efa8700b9dc8e6e53cd8ae = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_46871798a7584233a2af7b8d7eb949e0);
#
#
#         var popup_b1f9887fccba3f0fb9afc68ad8d82a15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e1bafdb4f11c08065654dfc2378989d = $(`&lt;div id=&quot;html_4e1bafdb4f11c08065654dfc2378989d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_b1f9887fccba3f0fb9afc68ad8d82a15.setContent(html_4e1bafdb4f11c08065654dfc2378989d);
#
#
#
#         marker_7675df93a1efa8700b9dc8e6e53cd8ae.bindPopup(popup_b1f9887fccba3f0fb9afc68ad8d82a15)
#         ;
#
#
#
#
#             var marker_e68423f7d23946efa970ecf25ca0d1e5 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_46871798a7584233a2af7b8d7eb949e0);
#
#
#         var popup_637bbdc02d48c6a72691f777d23e529f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f1c1d60ebbcf0d576880e18e7fad6e7 = $(`&lt;div id=&quot;html_9f1c1d60ebbcf0d576880e18e7fad6e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_637bbdc02d48c6a72691f777d23e529f.setContent(html_9f1c1d60ebbcf0d576880e18e7fad6e7);
#
#
#
#         marker_e68423f7d23946efa970ecf25ca0d1e5.bindPopup(popup_637bbdc02d48c6a72691f777d23e529f)
#         ;
#
#
#
#
#             var marker_0c33a1049a3afcc5f32c34046f3f1b23 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_46871798a7584233a2af7b8d7eb949e0);
#
#
#         var popup_526bc79b5ceb806d8db86670e3697be4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_684f10a50837e332dbe2744bd6b8e7f8 = $(`&lt;div id=&quot;html_684f10a50837e332dbe2744bd6b8e7f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_526bc79b5ceb806d8db86670e3697be4.setContent(html_684f10a50837e332dbe2744bd6b8e7f8);
#
#
#
#         marker_0c33a1049a3afcc5f32c34046f3f1b23.bindPopup(popup_526bc79b5ceb806d8db86670e

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles="Cartodb Positron")
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f49cfa4a85491bd61cc95f70783f652 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f49cfa4a85491bd61cc95f70783f652&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f49cfa4a85491bd61cc95f70783f652 = L.map(
#                 &quot;map_2f49cfa4a85491bd61cc95f70783f652&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df333e34b76f3c7256479768da884905 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f49cfa4a85491bd61cc95f70783f652);
#
#
#             var marker_cluster_8dcbe44764712f72e6e0dce064d103dd = L.markerClusterGroup(
#                 {}
#             );
#             map_2f49cfa4a85491bd61cc95f70783f652.addLayer(marker_cluster_8dcbe44764712f72e6e0dce064d103dd);
#
#
#             var marker_2022c9123a312ba6c39d8e2a898864d8 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_8dcbe44764712f72e6e0dce064d103dd);
#
#
#         var popup_569dd776c04b3fd6ce46e625ec36b339 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d39da06a28aee4e94412d01156fa3c94 = $(`&lt;div id=&quot;html_d39da06a28aee4e94412d01156fa3c94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_569dd776c04b3fd6ce46e625ec36b339.setContent(html_d39da06a28aee4e94412d01156fa3c94);
#
#
#
#         marker_2022c9123a312ba6c39d8e2a898864d8.bindPopup(popup_569dd776c04b3fd6ce46e625ec36b339)
#         ;
#
#
#
#
#             var marker_97f86f57e153f1bad5d482349f1a7e09 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_8dcbe44764712f72e6e0dce064d103dd);
#
#
#         var popup_79f7c9e6e37a4c0bca97f828792a0846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2bf5992e9c9606a072188e5688ae27d = $(`&lt;div id=&quot;html_b2bf5992e9c9606a072188e5688ae27d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_79f7c9e6e37a4c0bca97f828792a0846.setContent(html_b2bf5992e9c9606a072188e5688ae27d);
#
#
#
#         marker_97f86f57e153f1bad5d482349f1a7e09.bindPopup(popup_79f7c9e6e37a4c0bca97f828792a0846)
#         ;
#
#
#
#
#             var marker_ade533b9d54d6c33756772e6ef325bed = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_8dcbe44764712f72e6e0dce064d103dd);
#
#
#         var popup_fdbffac5240ae28fe6f5ea8ead844859 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a3e870feefe3f3bc075a4dab5fd5438 = $(`&lt;div id=&quot;html_6a3e870feefe3f3bc075a4dab5fd5438&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_fdbffac5240ae28fe6f5ea8ead844859.setContent(html_6a3e870feefe3f3bc075a4dab5fd5438);
#
#
#
#         marker_ade533b9d54d6c33756772e6ef325bed.bindPopup(popup_fdbffac5240ae28fe6f5ea8ead844859)
#         ;
#
#
#
#
#             var marker_a40496836af4029bae8fcee9058fda8c = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_8dcbe44764712f72e6e0dce064d103dd);
#
#
#         var popup_2a92b48012ce98001a104e5e54c05138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_329a650978c95041142dab2069eae9fd = $(`&lt;div id=&quot;html_329a650978c95041142dab2069eae9fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_2a92b48012ce98001a104e5e54c05138.setContent(html_329a650978c95041142dab2069eae9fd);
#
#
#
#         marker_a40496836af4029bae8fcee9058fda8c.bindPopup(popup_2a92b48012ce98001a104e5e54c05138)
#         ;
#
#
#
#
#             var marke

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.
